# %%
import pandas as pd
import itertools
from itertools import combinations

# %%
# Create the dataframe from the tabular data

data = {'Team': ['SRH', 'SRH', 'SRH', 'SRH', 'SRH', 'SRH', 'SRH', 'SRH', 'SRH', 'SRH', 'SRH', 'SRH', 'DC', 'DC', 'DC', 'DC', 'DC', 'DC', 'DC', 'DC', 'DC', 'DC', 'DC', 'DC', 'DC'],
        'Name': ['Harry Brook', 'Mayank Agarwal', 'Rahul Tripathi', 'Aiden Markram (c)', 'Abhishek Sharma LAO', 'Heinrich Klaasen', 'Abdul Samad', 'Marco Jansen LAF', 'Washington Sundar RAOB', 'Bhuvneshwar Kumar RAFM', 'Mayank Markande RALB', 'Umran Malik RAF', 'David Warner (c)', 'Prithvi Shaw', 'Mitchell Marsh', 'Yash Dhull RAOB', 'Manish Pandey', 'Abhishek Porel', 'Axar Patel LAO', 'Aman Khan RAFM', 'Lalit Yadav RAO', 'Anrich Nortje RAF', 'Kuldeep Yadav LACM', 'Rovman Powell', 'Mustafizur Rahman LAFM'],
        'Avg': [13.25, 8.25, 8.5, 2.6, 6.5, 5.25, 4, 4.2, 8.75, 4.2, 0.5, 4, 6.25, 7.5, 6.5, 0.5, 2.4, 0.2, 9, 0.2, 0.65, 6.5, 2, 2.8, 2],
        'Role': ['Bat', 'Bat', 'Bat', 'Bat', 'All', 'Wk', 'Bat', 'All', 'All', 'Bow', 'Bow', 'Bat', 'Bat', 'Bat', 'All', 'Bat', 'Bat', 'Wk', 'All', 'Bow', 'All', 'All', 'Bow', 'Bat', 'Bow'],
        'Form Team': ['Bat', '', 'Bat', 'Bat', '', 'Wk', '', 'All', '', '', 'Bow', 'Bat', 'Bat', '', 'All', 'Bat', 'Bat', 'Wk', 'All', 'Bow', 'All', 'Bow', 'Bow', 'Bat', 'Bow']
       }

# %% [markdown]
# ### 1. Get the 36 teams with all the CVC combinations of the Form Team

# %%
# Sort the dataframe by 'Avg' column in descending order and select the top 6 players
top_six = df[ df['Form Team'] != ''].sort_values(by='Avg', ascending=False).head(6)

team_number = 1

# Iterate through all possible captain and vice-captain combinations
for i in range(len(top_six)):
    captain = top_six.iloc[i]
    
    for j in range(len(top_six)):
        if i == j:
            continue

        vice_captain = top_six.iloc[j]
        team_number += 1

        # Create new column name for the combination
        col_name = f"FT{team_number}"

        # Create a new column for the combination, copying the initial 'FT1' column
        df[col_name] = df['Form Team']

        # Update the new column for captain and vice-captain
        df.loc[captain.name, col_name] += " + c"
        df.loc[vice_captain.name, col_name] += " + vc"
        
print("That's a wrap")
# Out:
# That's a wrap

# %%
exp_filename = 'allcvc_form_team'

df.to_csv(f"C:\\Users\\karan\\Documents\\IPL 2023\\{exp_filename}.csv")

# %% [markdown]
# ### 2 Each players deserves a captain-role

# %%
# Filter the top_six dataframe to include only the players in the 'Form Team' column
form_team = df[df['Form Team'] != '']
team_number = 1

# Iterate through all players in the 'Form Team' column
for i in range(len(form_team)):
    captain = form_team.iloc[i]

    # Remove captain from the list of possible vice-captains
    possible_vice_captains = form_team[form_team['Name'] != captain['Name']]

    # Randomly select a vice-captain from the remaining players
    vice_captain = possible_vice_captains.sample()

    # Create new column name for the combination
    col_name = f"FT{team_number}"

    # Create a new column for the combination, copying the initial 'FT1' column
    df[col_name] = df['Form Team']

    # Update the new column for captain and vice-captain
    df.loc[captain.name, col_name] += " + c"
    df.loc[vice_captain.index[0], col_name] += " + vc"
    
    team_number += 1

# %%
team_number = 0

#df['FT0'] = df['Form Team'].replace('', df['Role'])
#df['FT0'] = df['Form Team'].replace('', df['Role'])
df['FT0'] = df.apply(lambda row: row['Form Team'] if row['Form Team'] != '' else row['Role'], axis=1)

# Iterate through all players in the dataframe
for i in range(len(df)):
    team_number += 1
    captain = df.iloc[i]

    # Randomly select a vice-captain from the players in the 'Form Team'
    vice_captain = df[df['Form Team'] != ''].sample()

    # Create new column name for the combination
    col_name = f"FT{team_number}"

    # Create a new column for the combination, copying the initial 'FT1' column
    df[col_name] = df['Form Team']

    # Update the new column for captain and vice-captain
    df.loc[captain.name, col_name] = df.loc[captain.name, 'Role'] + " + c"
    df.loc[vice_captain.index[0], col_name] =  df.loc[vice_captain.index[0], 'Role'] + " + vc"

# %%
display(df)
# Out:
#    Team                    Name    Avg         Role Form Team  \
# 0   SRH             Harry Brook  13.25  Bat + c + c       Bat
# 18   DC          Axar Patel LAO   9.00     All + vc       All
# 8   SRH  Washington Sundar RAOB   8.75          All
# 2   SRH          Rahul Tripathi   8.50          Bat       Bat
# 1   SRH          Mayank Agarwal   8.25          Bat
# 13   DC            Prithvi Shaw   7.50          Bat
# 21   DC       Anrich Nortje RAF   6.50          All       Bow
# 4   SRH     Abhishek Sharma LAO   6.50          All
# 14   DC          Mitchell Marsh   6.50          All       All
# 12   DC        David Warner (c)   6.25          Bat       Bat
# 5   SRH        Heinrich Klaasen   5.25           Wk        Wk
# 7   SRH        Marco Jansen LAF   4.20          All       All
# 9   SRH  Bhuvneshwar Kumar RAFM   4.20          Bow
# 11  SRH         Umran Malik RAF   4.00          Bat       Bat
# 6   SRH             Abdul Samad   4.00          Bat
# 23   DC           Rovman Powell   2.80          Bat       Bat
# 3   SRH       Aiden Markram (c)   2.60          Bat       Bat
# 16   DC           Manish Pandey   2.40          Bat       Bat
# 22   DC      Kuldeep Yadav LACM   2.00          Bow       Bow
# 24   DC  Mustafizur Rahman LAFM   2.00          Bow       Bow
# 20   DC         Lalit Yadav RAO   0.65          All       All
# 10  SRH    Mayank Markande RALB   0.50          Bow       Bow
# 15   DC         Yash Dhull RAOB   0.50          Bat       Bat
# 17   DC          Abhishek Porel   0.20           Wk        Wk
# 19   DC          Aman Khan RAFM   0.20          Bow       Bow
#
#                 FT1           FT2       FT3      FT4       FT5  ...     FT23  \
# 0   Bat + c + c + c           Bat       Bat      Bat       Bat  ...      Bat
# 18              All  All + vc + c       All      All       All  ...      All
# 8                                   All + c                     ...
# 2               Bat           Bat       Bat  Bat + c       Bat  ...      Bat
# 1                                                      Bat + c  ...
# 13                                                              ...
# 21         All + vc           Bow       Bow      Bow  All + vc  ...      Bow
# 4                                                               ...
# 14              All           All       All      All       All  ...      All
# 12              Bat           Bat       Bat      Bat       Bat  ...      Bat
# 5                Wk       Wk + vc        Wk  Wk + vc        Wk  ...  Wk + vc
# 7               All           All       All      All       All  ...      All
# 9                                                               ...
# 11              Bat           Bat       Bat      Bat       Bat  ...      Bat
# 6                                                               ...
# 23              Bat           Bat       Bat      Bat       Bat  ...      Bat
# 3               Bat           Bat       Bat      Bat       Bat  ...      Bat
# 16              Bat           Bat  Bat + vc      Bat       Bat  ...      Bat
# 22              Bow           Bow       Bow      Bow       Bow  ...      Bow
# 24              Bow           Bow       Bow      Bow       Bow  ...      Bow
# 20              All           All       All      All       All  ...      All
# 10              Bow           Bow       Bow      Bow       Bow  ...      Bow
# 15              Bat           Bat       Bat      Bat       Bat  ...  Bat + c
# 17               Wk            Wk        Wk       Wk        Wk  ...       Wk
# 19              Bow           Bow       Bow      Bow       Bow  ...      Bow
#
#         FT24      FT25      FT26      FT27      FT28      FT29      FT30  \
# 0        Bat       Bat       Bat  Bat + vc       Bat       Bat       Bat
# 18       All       All       All       All  All + vc       All       All
# 8
# 2        Bat       Bat       Bat       Bat       Bat  Bat + vc       Bat
# 1
# 13
# 21       Bow       Bow       Bow       Bow       Bow       Bow  Bow + vc
# 4
# 14       All  All + vc   All + c       All       All       All       All
# 12       Bat       Bat  Bat + vc   Bat + c   Bat + c   Bat + c   Bat + c
# 5         Wk        Wk        Wk        Wk        Wk        Wk        Wk
# 7   All + vc       All       All       All       All       All       All
# 9
# 11       Bat       Bat       Bat       Bat       Bat       Bat       Bat
# 6
# 23       Bat       Bat       Bat       Bat       Bat       Bat       Bat
# 3        Bat       Bat       Bat       Bat       Bat       Bat       Bat
# 16       Bat       Bat       Bat       Bat       Bat       Bat       Bat
# 22       Bow       Bow       Bow       Bow       Bow       Bow       Bow
# 24       Bow       Bow       Bow       Bow       Bow       Bow       Bow
# 20       All       All       All       All       All       All       All
# 10       Bow       Bow       Bow       Bow       Bow       Bow       Bow
# 15       Bat       Bat       Bat       Bat       Bat       Bat       Bat
# 17    Wk + c        Wk        Wk        Wk        Wk        Wk        Wk
# 19       Bow   Bow + c       Bow       Bow       Bow       Bow       Bow
#
#         FT31  FT0
# 0        Bat  Bat
# 18       All  All
# 8             All
# 2        Bat  Bat
# 1             Bat
# 13            Bat
# 21       Bow  Bow
# 4             All
# 14  All + vc  All
# 12   Bat + c  Bat
# 5         Wk   Wk
# 7        All  All
# 9             Bow
# 11       Bat  Bat
# 6             Bat
# 23       Bat  Bat
# 3        Bat  Bat
# 16       Bat  Bat
# 22       Bow  Bow
# 24       Bow  Bow
# 20       All  All
# 10       Bow  Bow
# 15       Bat  Bat
# 17        Wk   Wk
# 19       Bow  Bow
#
# [25 rows x 37 columns]

# %%
exp_filename_allcaps = 'all_captains'
df.to_csv(f"C:\\Users\\karan\\Documents\\IPL 2023\\{exp_filename_allcaps}.csv")
