# %%
import os, json
import numpy as np, pandas as pd, math

from pprint import pprint
from datetime import datetime as dt

# %%
location = 'C:\\Users\\karan\\Documents\\Cricket-Analytics\\IPL\\Data\\ipl_json'
exp_location = 'C:\\Users\\karan\\Documents\\Cricket-Analytics\\IPL\\Data\\ipl_json_bbb\\'

# %%
print(location)
print()
print(dt.now().date())
# Out:
# C:\Users\karan\Documents\Cricket-Analytics\IPL\Data\ipl_json
#
# 2023-05-02

# %%
folder_path = location

# Get a list of all files and directories in the folder
all_files_and_dirs = os.listdir(folder_path)

# Filter the list to include only files (exclude directories)
files_only = [f for f in all_files_and_dirs if os.path.isfile(os.path.join(folder_path, f))]

# Print total # of files
print(len(files_only))

# Print names of first few files 
print(files_only[:5])
# Out:
# 975
# ['1082591.json', '1082592.json', '1082593.json', '1082594.json', '1082595.json']

# %%
files_list = files_only
total_files = len(files_list)

#print(np.arange(total_files))
print(total_files)
# Out:
# 975

# %%
#All file numbers > 1359475 are #2023 IPL onwards
#All file numbers > 1304047 are #2022 IPL onwards

# %%
# DEBUGGING

for filenum in np.arange(total_files):

    import_filename = files_only[filenum].replace('.json','')
    print(import_filename)
    
    if (import_filename != 'README.txt') :
        if ( int(import_filename) == 1359493 ):
            # Replace 'file.json' with the path to your JSON file
            json_file_path = location + '\\' + files_only[filenum]
            print(json_file_path)



            #adding a check to see if json file is empty before reading it with pd.read_json.

            if os.path.getsize(json_file_path) > 0:
                # Can't read it directly because of multiple structures inside the json file
                #df = pd.read_json(json_file_path)

                # let's try to flatten it and then import it
                with open(json_file_path, 'r', encoding='utf-8') as file:
                    json_content = json.load(file)

                # Flatten the nested JSON content
                df = pd.json_normalize(json_content)

            else:
                print("The JSON file is empty.")
# Out:
# 1082591
# 1082592
# 1082593
# 1082594
# 1082595
# 1082596
# 1082597
# 1082598
# 1082599
# 1082600
# 1082601
# 1082602
# 1082603
# 1082604
# 1082605
# 1082606
# 1082607
# 1082608
# 1082609
# 1082610
# 1082611
# 1082612
# 1082613
# 1082614
# 1082615
# 1082616
# 1082617
# 1082618
# 1082620
# 1082621
# 1082622
# 1082623
# 1082624
# 1082625
# 1082626
# 1082627
# 1082628
# 1082629
# 1082630
# 1082631
# 1082632
# 1082633
# 1082634
# 1082635
# 1082636
# 1082637
# 1082638
# 1082639
# 1082640
# 1082641
# 1082642
# 1082643
# 1082644
# 1082645
# 1082646
# 1082647
# 1082648
# 1082649
# 1082650
# 1136561
# 1136562
# 1136563
# 1136564
# 1136565
# 1136566
# 1136567
# 1136568
# 1136569
# 1136570
# 1136571
# 1136572
# 1136573
# 1136574
# 1136575
# 1136576
# 1136577
# 1136578
# 1136579
# 1136580
# 1136581
# 1136582
# 1136583
# 1136584
# 1136585
# 1136586
# 1136587
# 1136588
# 1136589
# 1136590
# 1136591
# 1136592
# 1136593
# 1136594
# 1136595
# 1136596
# 1136597
# 1136598
# 1136599
# 1136600
# 1136601
# ...

# %%
pprint(json_content)
# Out:
# {'info': {'balls_per_over': 6,
#           'city': 'Kolkata',
#           'dates': ['2023-04-14'],
#           'event': {'match_number': 19, 'name': 'Indian Premier League'},
#           'gender': 'male',
#           'match_type': 'T20',
#           'officials': {'match_referees': ['DS Manohar'],
#                         'reserve_umpires': ['M Kuppuraj'],
#                         'tv_umpires': ['NA Patwardhan'],
#                         'umpires': ['CB Gaffaney', 'GR Sadashiv Iyer']},
#           'outcome': {'by': {'runs': 23}, 'winner': 'Sunrisers Hyderabad'},
#           'overs': 20,
#           'player_of_match': ['HC Brook'],
#           'players': {'Kolkata Knight Riders': ['Suyash Sharma',
#                                                 'Rahmanullah Gurbaz',
#                                                 'N Jagadeesan',
#                                                 'VR Iyer',
#                                                 'SP Narine',
# ...

# %%
pprint(json_content['info']['city'])
pprint(json_content['info']['dates'][0])
pprint(json_content['info']['event']['match_number'])
pprint(json_content['info']['match_type'])
pprint(json_content['info']['season'])
pprint(json_content['info']['teams'][0])
pprint(json_content['info']['teams'][1])

print()

pprint(json_content['info'])
# Out:
# 'Kolkata'
# '2023-04-14'
# 19
# 'T20'
# '2023'
# 'Sunrisers Hyderabad'
# 'Kolkata Knight Riders'
#
# {'balls_per_over': 6,
#  'city': 'Kolkata',
#  'dates': ['2023-04-14'],
#  'event': {'match_number': 19, 'name': 'Indian Premier League'},
#  'gender': 'male',
#  'match_type': 'T20',
#  'officials': {'match_referees': ['DS Manohar'],
#                'reserve_umpires': ['M Kuppuraj'],
#                'tv_umpires': ['NA Patwardhan'],
#                'umpires': ['CB Gaffaney', 'GR Sadashiv Iyer']},
#  'outcome': {'by': {'runs': 23}, 'winner': 'Sunrisers Hyderabad'},
#  'overs': 20,
#  'player_of_match': ['HC Brook'],
#  'players': {'Kolkata Knight Riders': ['Suyash Sharma',
#                                        'Rahmanullah Gurbaz',
#                                        'N Jagadeesan',
#                                        'VR Iyer',
#                                        'SP Narine',
#                                        'N Rana',
# ...

# %%
for filenum in np.arange(total_files):

    import_filename = files_only[filenum].replace('.json','')
    #print(import_filename)
    
    if (import_filename != 'README.txt') :    
        if int(import_filename) >= 1359475:

            json_file_path = location + '\\' + files_only[filenum]
            print(json_file_path)

            #adding a check to see if json file is empty before reading it with pd.read_json.

            if os.path.getsize(json_file_path) > 0:
                # Can't read it directly because of multiple structures inside the json file
                #df = pd.read_json(json_file_path)

                # let's try to flatten it and then import it
                with open(json_file_path, 'r', encoding='utf-8') as file:
                    json_content = json.load(file)

                # Flatten the nested JSON content
                df = pd.json_normalize(json_content)
            
            #df_innings = pd.DataFrame(columns = colslist)
                        
            colslist = ['inn','bat_tm','batnum','bat','ball','over_num','bow','runs','wkt','wkt_how', 'b.cnt']
            dfbbb = pd.DataFrame(columns = colslist)
            
            

            for innings in [0,1]:
                batter_num_dict = {}               
                batter_num = 0
                
                #print(type(json_content['innings'][innings]['overs']))
                overs_in_this_inn = len(json_content['innings'][innings]['overs'])

                bat_tm = json_content['innings'][innings]['team']
                print(f'Over in Innings is {overs_in_this_inn}')
                
                for over_num in np.arange(0,overs_in_this_inn,1):
                    balls_in_over = len(json_content['innings'][innings]['overs'][over_num]['deliveries'])

                    for ball_num in np.arange(0,balls_in_over,1):
                        #print(json_content['innings'][innings]['overs'][over_num]['deliveries'][ball_num])
                        
                        # Need to get match details, who v who, batter, bowler, over number, ball number, runs score, extras, batter runs, bowler runs , wickets
                        
                        #over_num is for variable
                        
                        bcnt = 1
                        wkt = 0
                        wkt_how = None
                        
                        bat_on_str = json_content['innings'][innings]['overs'][over_num]['deliveries'][ball_num]['batter']
                        
                        if bat_on_str in batter_num_dict:
                            pass
                        else:
                            batter_num = batter_num + 1
                            batter_num_dict[bat_on_str] = batter_num
                        
                        
                        bow = json_content['innings'][innings]['overs'][over_num]['deliveries'][ball_num]['bowler']
                        runs_to_bat = json_content['innings'][innings]['overs'][over_num]['deliveries'][ball_num]['runs']['batter']
                        
                        if 'wickets' in json_content['innings'][innings]['overs'][over_num]['deliveries'][ball_num]:
                            wkt = 1
                            
                        if 'extras' in json_content['innings'][innings]['overs'][over_num]['deliveries'][ball_num]:
                            if ('noballs' in json_content['innings'][innings]['overs'][over_num]['deliveries'][ball_num]['extras']) or ('wides' in json_content['innings'][innings]['overs'][over_num]['deliveries'][ball_num]['extras']):
                                bcnt = 0                        

                        this_ball_details_row = [innings+1, bat_tm, batter_num_dict[bat_on_str], bat_on_str, ball_num, over_num, bow, runs_to_bat, wkt, wkt_how, bcnt]
                        dfbbb.loc[len(dfbbb)] = this_ball_details_row
                        
                            
                        """
                        wkt = 0
                        wkt_how = ''
                        ball = 1

                        #print(len(json_content['innings'][innings]['overs'][over_num]['deliveries'][ball_num]))
                        bat_on_str = json_content['innings'][innings]['overs'][over_num]['deliveries'][ball_num]['batter']
                        bow = json_content['innings'][innings]['overs'][over_num]['deliveries'][ball_num]['bowler']
                        runs_to_bat = json_content['innings'][innings]['overs'][over_num]['deliveries'][ball_num]['runs']['batter']

                        if 'wickets' in json_content['innings'][innings]['overs'][over_num]['deliveries'][ball_num]:
                            wkt = 1
                            wkt_how = json_content['innings'][innings]['overs'][over_num]['deliveries'][ball_num]['wickets'][0]['kind']
                            
                        if 'extras' in json_content['innings'][innings]['overs'][over_num]['deliveries'][ball_num]:
                            if ('noballs' in json_content['innings'][innings]['overs'][over_num]['deliveries'][ball_num]['extras']) or ('wides' in json_content['innings'][innings]['overs'][over_num]['deliveries'][ball_num]['extras']):
                                ball = 0
                        """
            
            dfbbb['f.ov.powp'] = dfbbb['over_num'].apply(lambda x : 1 if x <= 5 else 0)
            dfbbb['f.ov.midd'] = dfbbb['over_num'].apply(lambda x : 1 if (x > 5) & (x < 16) else 0)
            dfbbb['f.ov.deat'] = dfbbb['over_num'].apply(lambda x : 1 if x >= 16 else 0)
            
            dfbbb['m.grnd'] = json_content['info']['city']
            dfbbb['m.date'] = json_content['info']['dates'][0]
            dfbbb['ss'] = json_content['info']['season']
            dfbbb['m.type'] = json_content['info']['match_type']
            dfbbb['m.num'] = json_content['info']['event']['match_number']
            dfbbb['m.vs'] = json_content['info']['teams'][0] + ' vs ' + json_content['info']['teams'][1]
            
            m_ss = json_content['info']['season']
            m_num = json_content['info']['event']['match_number']
            m_vs = json_content['info']['teams'][0] + ' vs ' + json_content['info']['teams'][1]
            
            pprint(json_content['info']['event']['match_number'])
            pprint(json_content['info']['teams'][0] + ' vs ' + json_content['info']['teams'][1])
            print()
            
            exp_fname = m_ss + '_' + str(m_num) + '_' + m_vs 
            
            dfbbb.to_csv(exp_location + exp_fname + '.csv', index = False)
# Out:
# C:\Users\karan\Documents\Cricket-Analytics\IPL\Data\ipl_json\1359475.json
# Over in Innings is 20
# Over in Innings is 20
# 1
# 'Chennai Super Kings vs Gujarat Titans'
#
# C:\Users\karan\Documents\Cricket-Analytics\IPL\Data\ipl_json\1359476.json
# Over in Innings is 20
# Over in Innings is 16
# 2
# 'Punjab Kings vs Kolkata Knight Riders'
#
# C:\Users\karan\Documents\Cricket-Analytics\IPL\Data\ipl_json\1359477.json
# Over in Innings is 20
# Over in Innings is 20
# 3
# 'Lucknow Super Giants vs Delhi Capitals'
#
# C:\Users\karan\Documents\Cricket-Analytics\IPL\Data\ipl_json\1359478.json
# Over in Innings is 20
# Over in Innings is 20
# 4
# 'Rajasthan Royals vs Sunrisers Hyderabad'
#
# C:\Users\karan\Documents\Cricket-Analytics\IPL\Data\ipl_json\1359479.json
# Over in Innings is 20
# Over in Innings is 17
# 5
# 'Mumbai Indians vs Royal Challengers Bangalore'
#
# C:\Users\karan\Documents\Cricket-Analytics\IPL\Data\ipl_json\1359480.json
# Over in Innings is 20
# Over in Innings is 20
# 6
# ...

# %%
print(dfbbb.shape)
print(dfbbb.columns.values.tolist())
# Out:
# (252, 20)
# ['inn', 'bat_tm', 'batnum', 'bat', 'ball', 'over_num', 'bow', 'runs', 'wkt', 'wkt_how', 'b.cnt', 'f.ov.powp', 'f.ov.midd', 'f.ov.deat', 'm.grnd', 'm.date', 'ss', 'm.type', 'm.num', 'm.vs']

# %%
#display(dfbbb.groupby(['f.ov.powp', 'f.ov.midd', 'f.ov.deat','over_num']).agg({'inn':'count'}).reset_index())
display(dfbbb.groupby(['f.ov.powp', 'f.ov.midd', 'f.ov.deat']).agg({'inn':'count'}).reset_index())
# Out:
#    f.ov.powp  f.ov.midd  f.ov.deat  inn
# 0          0          0          1   56
# 1          0          1          0  124
# 2          1          0          0   72

# %%
display(dfbbb.head(2)
# Out:
#     inn                       bat_tm batnum              bat ball over_num  \
# 0     1          Chennai Super Kings      1       RD Gaikwad    0        0
# 1     1          Chennai Super Kings      2        DP Conway    1        0
# 2     1          Chennai Super Kings      2        DP Conway    2        0
# 3     1          Chennai Super Kings      2        DP Conway    3        0
# 4     1          Chennai Super Kings      2        DP Conway    4        0
# ..   ..                          ...    ...              ...  ...      ...
# 247   2  Royal Challengers Bangalore      9     PWH de Silva    1       19
# 248   2  Royal Challengers Bangalore      7  SS Prabhudessai    2       19
# 249   2  Royal Challengers Bangalore      7  SS Prabhudessai    3       19
# 250   2  Royal Challengers Bangalore      7  SS Prabhudessai    4       19
# 251   2  Royal Challengers Bangalore      7  SS Prabhudessai    5       19
#
# ...

# %%
dfbbb['m.vs'].unique()
# Out:
# array(['Chennai Super Kings vs Royal Challengers Bangalore'], dtype=object)

# %%
"""
for filenum in np.arange(total_files):

    import_filename = files_only[filenum].replace('.json','')
    print(import_filename)
    
    if (import_filename != 'README.txt') :    
        if int(import_filename) >= 1359475:
            # Replace 'file.json' with the path to your JSON file
            json_file_path = location + '\\' + files_only[filenum]
            print(json_file_path)

            #adding a check to see if json file is empty before reading it with pd.read_json.

            if os.path.getsize(json_file_path) > 0:
                # Can't read it directly because of multiple structures inside the json file
                #df = pd.read_json(json_file_path)

                # let's try to flatten it and then import it
                with open(json_file_path, 'r', encoding='utf-8') as file:
                    json_content = json.load(file)

                # Flatten the nested JSON content
                df = pd.json_normalize(json_content)

            else:
                print("The JSON file is empty.")

            i_ss = json_content['info']['season']
            i_mtype = json_content['info']['match_type']
            i_date = json_content['info']['dates'][0].replace('-','_')
            i_city = json_content['info']['city']
            i_tms = json_content['info']['teams'][0] + '_v_' + json_content['info']['teams'][1]
            
            i_match_num = json_content['info']['event']['match_number']

            info_ = [i_match_num, i_ss, i_mtype, i_date, i_city, i_tms ]

            print(info_)
            #json_content['info']['dates'].pop()

            tms_lst = json_content['info']['teams']

            print(tms_lst)




            # looping through the json file(s) to put into dataframe

            colslist = ['mnum','inn','bat_tm','bat','ball','bow','runs','wkt','wkt_how']

            df_innings = pd.DataFrame(columns = colslist)


            for innings in [0,1]:
                print(type(json_content['innings'][innings]['overs']))
                overs_in_this_inn = len(json_content['innings'][innings]['overs'])

                bat_tm = json_content['innings'][innings]['team']
                print(f'Over in Innings is {overs_in_this_inn}')
                for over_num in np.arange(0,overs_in_this_inn,1):
                    #print(len(json_content['innings'][innings]['overs'][over_num]['deliveries']))

                    balls_in_over = len(json_content['innings'][innings]['overs'][over_num]['deliveries'])
                    for ball_num in np.arange(0,balls_in_over,1):
                        wkt = 0
                        wkt_how = ''
                        ball = 1

                        #print(len(json_content['innings'][innings]['overs'][over_num]['deliveries'][ball_num]))
                        bat_on_str = json_content['innings'][innings]['overs'][over_num]['deliveries'][ball_num]['batter']
                        bow = json_content['innings'][innings]['overs'][over_num]['deliveries'][ball_num]['bowler']
                        runs_to_bat = json_content['innings'][innings]['overs'][over_num]['deliveries'][ball_num]['runs']['batter']

                        if 'wickets' in json_content['innings'][innings]['overs'][over_num]['deliveries'][ball_num]:
                            wkt = 1
                            wkt_how = json_content['innings'][innings]['overs'][over_num]['deliveries'][ball_num]['wickets'][0]['kind']
                            
                        if 'extras' in json_content['innings'][innings]['overs'][over_num]['deliveries'][ball_num]:
                            if ('noballs' in json_content['innings'][innings]['overs'][over_num]['deliveries'][ball_num]['extras']) or ('wides' in json_content['innings'][innings]['overs'][over_num]['deliveries'][ball_num]['extras']):
                                ball = 0

                        this_ball_details_row = [i_match_num, innings+1, bat_tm, bat_on_str, ball, bow, runs_to_bat, wkt, wkt_how]
                        #print(this_ball_details_row)
                        df_innings.loc[len(df_innings)] = this_ball_details_row


            df_innings['four'] = df_innings['runs'].apply(lambda x : 1 if x==4 else 0)
            df_innings['six'] = df_innings['runs'].apply(lambda x : 1 if x==6 else 0)

            df_innings['bow_tm'] = df_innings.apply(lambda x: next(item for item in tms_lst if item != x.bat_tm), axis=1)

            df_innings.head()

            #batter rollup

            df_bat_stats = df_innings.groupby(['bat_tm','bow_tm','inn','bat','mnum'])\
            .agg({'runs':'sum','four':'sum','six':'sum','wkt':'sum', 'ball':'sum'})\
                .reset_index().rename(columns = {'runs':'rs','ball':'bowf','wkt':'out','inn':'inn_bat','bat':'name'})

            print(df_bat_stats.columns.values.tolist())
            print(df_bat_stats.shape)

            #df_bat_stats['bow_tm'] = df_bat_stats.apply(lambda x : [item for item in two_member_list if item != character_variable] , axis = 1)
            #df_bat_stats['bow_tm'] = df_bat_stats.apply(lambda x : item for item in tms_list if item != x.bat_tm , axis = 1)

            display(df_bat_stats.head())

            #batter rollup

            df_bow_stats = df_innings.groupby(['bow','bow_tm','bat_tm','inn','mnum']).agg({'runs':'sum', 'ball':'sum','wkt':'sum'})\
                .reset_index().rename(columns = {'runs':'rc','ball':'balb','inn':'inn_bow','bow':'name'})

            print(df_bow_stats.columns.values.tolist())
            print(df_bow_stats.shape)

            df_bow_stats['inn_bat'] = df_bow_stats['inn_bow'].apply(lambda x : 2 if x==1 else 1 )

            display(df_bow_stats.head())




            print(df_bow_stats.shape)
            print(df_bat_stats.shape)

            df_match = pd.merge( df_bat_stats, df_bow_stats\
                                , left_on = ['bow_tm','bat_tm','inn_bat','name','mnum']
                                , right_on = ['bat_tm','bow_tm','inn_bat','name','mnum']
                                , how = 'outer'
                                , suffixes=('_inn1', '_inn2') ) 

            print(df_match.shape)


            display(df_match.sort_values(by = ['inn_bat']))


            df_match['season'] = i_ss
            df_match['type'] = i_mtype
            df_match['date'] = i_date
            df_match['city'] = i_city
            df_match['teams'] = i_tms
            
            df_match['bat_tm_inn1'] = df_match['bat_tm_inn1'].astype(str)
            df_match['bow_tm_inn2'] = df_match['bow_tm_inn2'].astype(str)
            
            df_match['team_nm'] = df_match.apply(lambda x : x.bow_tm_inn2 if ( x.bat_tm_inn1 == 'nan') else x.bat_tm_inn1, axis = 1)
            #df_match['team_nm'] = df_match['bat_tm_inn1'] + df_match['bow_tm_inn2']

            display(df_match.head())

            export_fname = import_filename + '_' + i_mtype + '_' + str(i_ss) + '_' + str(i_match_num) + '_' + i_date + '_' + i_tms + '.csv'

            print(export_fname)
            
            dropcols = ['bat_tm_inn1','bat_tm_inn2','bow_tm_inn1','bow_tm_inn2']
            df_match_exp = df_match.sort_values(by='inn_bat').drop(columns = dropcols)

            df_match_exp.to_csv( exp_location + '\\' + export_fname, index = False )

"""
# Out:
# '\nfor filenum in np.arange(total_files):\n\n    import_filename = files_only[filenum].replace(\'.json\',\'\')\n    print(import_filename)\n    \n    if (import_filename != \'README.txt\') :    \n        if int(import_filename) >= 1359475:\n            # Replace \'file.json\' with the path to your JSON file\n            json_file_path = location + \'\\\' + files_only[filenum]\n            print(json_file_path)\n\n            #adding a check to see if json file is empty before reading it with pd.read_json.\n\n            if os.path.getsize(json_file_path) > 0:\n                # Can\'t read it directly because of multiple structures inside the json file\n                #df = pd.read_json(json_file_path)\n\n                # let\'s try to flatten it and then import it\n                with open(json_file_path, \'r\', encoding=\'utf-8\') as file:\n                    json_content = json.load(file)\n\n                # Flatten the nested JSON content\n                df = pd.json_normal
# ...
